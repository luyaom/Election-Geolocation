# %%
import pandas as pd

# %%
election_data = pd.read_csv('US_County_Level_Election_Results_08-16-master/US_County_Level_Presidential_Results_08-16.csv', dtype={'fips_code':str})
print(election_data.shape)
print(election_data.head())
# Out:
# (3112, 14)
#   fips_code              county  total_2008  dem_2008  gop_2008  oth_2008  \
# 0     26041        Delta County       19064      9974      8763       327
# 1     48295     Lipscomb County        1256       155      1093         8
# 2     01127       Walker County       28652      7420     20722       510
# 3     48389       Reeves County        3077      1606      1445        26
# 4     56017  Hot Springs County        2546       619      1834        93
#
#    total_2012  dem_2012  gop_2012  oth_2012  total_2016  dem_2016  gop_2016  \
# 0       18043      8330      9533       180       18467      6431     11112
# 1        1168       119      1044         5        1322       135      1159
# 2       28497      6551     21633       313       29243      4486     24208
# 3        2867      1649      1185        33        3184      1659      1417
# 4        2495       523      1894        78        2535       400      1939
#
#    oth_2016
# 0       924
# 1        28
# 2       549
# 3       108
# 4       196

# %%
election_data['2008_dem_ratio'] = election_data['dem_2008'] / election_data['total_2008']
election_data['2012_dem_ratio'] = election_data['dem_2012'] / election_data['total_2012']
election_data['2016_dem_ratio'] = election_data['dem_2016'] / election_data['total_2016']

# %%
election_data['2008_gop_ratio'] = election_data['gop_2008'] / election_data['total_2008']
election_data['2012_gop_ratio'] = election_data['gop_2012'] / election_data['total_2012']
election_data['2016_gop_ratio'] = election_data['gop_2016'] / election_data['total_2016']

# %%
election_data['2008_oth_ratio'] = election_data['oth_2008'] / election_data['total_2008']
election_data['2012_oth_ratio'] = election_data['oth_2012'] / election_data['total_2012']
election_data['2016_oth_ratio'] = election_data['oth_2016'] / election_data['total_2016']

# %%
election_data['2008_result'] = ['dem' if dem > gop else 'gop' for (dem, gop) in zip(election_data['dem_2008'], election_data['gop_2008'])]
election_data['2012_result'] = ['dem' if dem > gop else 'gop' for (dem, agop) in zip(election_data['dem_2012'], election_data['gop_2012'])]
election_data['2016_result'] = ['dem' if dem > gop else 'gop' for (dem, gop) in zip(election_data['dem_2016'], election_data['gop_2016'])]

# %%
election_data.head()
# Out:
#   fips_code              county  total_2008  dem_2008  gop_2008  oth_2008  \
# 0     26041        Delta County       19064      9974      8763       327
# 1     48295     Lipscomb County        1256       155      1093         8
# 2     01127       Walker County       28652      7420     20722       510
# 3     48389       Reeves County        3077      1606      1445        26
# 4     56017  Hot Springs County        2546       619      1834        93
#
#    total_2012  dem_2012  gop_2012  oth_2012      ...        2012_dem_ratio  \
# 0       18043      8330      9533       180      ...              0.461675
# 1        1168       119      1044         5      ...              0.101884
# 2       28497      6551     21633       313      ...              0.229884
# 3        2867      1649      1185        33      ...              0.575166
# 4        2495       523      1894        78      ...              0.209619
#
#    2016_dem_ratio  2012_result  2016_result 2008_gop_ratio  2012_gop_ratio  \
# 0        0.348243          gop          gop       0.459662        0.528349
# 1        0.102118          gop          gop       0.870223        0.893836
# 2        0.153404          gop          gop       0.723230        0.759133
# 3        0.521043          dem          dem       0.469613        0.413324
# 4        0.157791          gop          gop       0.720346        0.759118
#
#    2016_gop_ratio  2008_oth_ratio 2012_oth_ratio 2016_oth_ratio
# 0        0.601722        0.017153       0.009976       0.050035
# 1        0.876702        0.006369       0.004281       0.021180
# 2        0.827822        0.017800       0.010984       0.018774
# 3        0.445038        0.008450       0.011510       0.033920
# 4        0.764892        0.036528       0.031263       0.077318
#
# [5 rows x 26 columns]

# %%
election_data.to_csv('election_data.csv', index=False)

# %%
election_data.loc[(election_data['dem_2008']+election_data['gop_2008']+election_data['oth_2008'])!=election_data['total_2008']]
# Out:
#      fips_code          county  total_2008  dem_2008  gop_2008  oth_2008  \
# 79       55111     Sauk County       30626     18167     11562       447
# 284      39123   Ottawa County       23069     12064     10618       402
# 1467     18091  LaPorte County      208757     28258     17918       743
# 1648     29105  Laclede County        2024      5218     10875       230
# 2033     29165   Platte County       46480     21495     24460       561
#
#       total_2012  dem_2012  gop_2012  oth_2012  total_2016  dem_2016  \
# 79         31832     18718     12829       285       33848     16050
# 284        21936     11214     10323       399       21742      8136
# 1467       43657     24104     18609       944       44994     19795
# 1648       15361      4093     10934       334       15959      2543
# 2033       45547     19171     25617       759       46641     18915
#
#       gop_2016  oth_2016 2008_result  2008_dem_ratio  2012_dem_ratio  \
# 79       15871      1927         dem        0.593189        0.588025
# 284      12389      1217         dem        0.522953        0.511214
# 1467     22678      2521         dem        0.135363        0.552122
# 1648     12834       582         gop        2.578063        0.266454
# 2033     24975      2751         gop        0.462457        0.420906
#
#       2016_dem_ratio 2012_result 2016_result
# 79          0.474179         dem         dem
# 284         0.374207         dem         gop
# 1467        0.439948         dem         gop
# 1648        0.159346         gop         gop
# 2033        0.405544         gop         gop
